# %% [markdown]
# # Exercizes on quality metrics

# %% [markdown]
# ## Some import and methods you can ignore

# %%
from ex_utils import *
# %matplotlib inline

# %% [markdown]
# ## Start here for your exercize

# %% [markdown]
# Select here how many queries you want to test and how many retrieved documents for each query.
#
# You can leave 0 to have a random exercize:

# %%
number_of_queries=0
number_of_documents_per_queries=0
Q,R=propose_exercize(number_of_queries, number_of_documents_per_queries)
# Out:
# Your IR system received 3 queries from users
# Here are the top 4 results your system retrieved for each query, and the correct evaluation for each of them
# d	q1	Rel		q2	Rel		q3	Rel
# #1	2	0		4	1		3	1
# #2	4	0		2	0		4	0
# #3	3	1		5	1		5	1
# #4	5	0		3	0		2	0

# %% [markdown]
# Select here which exercise you want to solve between:
# * 'prec_rec': draw the Precision-Recall curve for each query;
# * 'r-prec': Determine the R-precision for each query;
# * 'map': Calculate the Mean Average Precision;
# * 'roc': Draw the Receiver-Operating-Characteristic for each query;
# * 'auc': Compute the Area Under the ROC curve;
# * 'all': all of the above;
# * 'clear': cleans the solution space

# %%
exercise='all' 
solve(exercise,Q,R)
# Out:
# Precision and Recall at k for k=1,...,6
# 	Query 1
# 		P(1)=1/1=1.00,	R(1)=1/4=0.25
# 		P(2)=2/2=1.00,	R(2)=2/4=0.50
# 		P(3)=2/3=0.67,	R(3)=2/4=0.50
# 		P(4)=2/4=0.50,	R(4)=2/4=0.50
# 		P(5)=3/5=0.60,	R(5)=3/4=0.75
# 		P(6)=4/6=0.67,	R(6)=4/4=1.00
# 	Query 2
# 		P(1)=0/1=0.00,	R(1)=0/3=0.00
# 		P(2)=1/2=0.50,	R(2)=1/3=0.33
# 		P(3)=1/3=0.33,	R(3)=1/3=0.33
# 		P(4)=1/4=0.25,	R(4)=1/3=0.33
# 		P(5)=2/5=0.40,	R(5)=2/3=0.67
# 		P(6)=3/6=0.50,	R(6)=3/3=1.00
#
#  Draw the Precision-Recall curve for each query
# 	Query 1
# 	Query 2
#  Determine R-precision for each query
# 	Query 1
# 		Number of relevant documents: 4 --> P(4)=0.50
# 	Query 2
# 		Number of relevant documents: 3 --> P(3)=0.33
#
#  Calculate the Mean Average Precision
# 	Query 1
# 		AP=1/4 {P(1) + P(2) + P(5) + P(6)}=0.82
# 	Query 2
# 		AP=1/3 {P(2) + P(5) + P(6)}=0.47
# 	MAP=1/2 {AP_1 + AP_2}=1/2 {0.82 + 0.47}=0.64
# TP_rate and FP_rate at k for k=1,...,6
# 	Query 1
# 		TP_rate(1)=R(1)=1/4=0.25	 FP_rate(1)=0/2=0.00
# ...
